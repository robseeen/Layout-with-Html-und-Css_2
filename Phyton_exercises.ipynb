# %% [markdown]
# <a href="https://colab.research.google.com/github/robseeen/Layout-with-Html-und-Css_2/blob/main/Phyton_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x=27

# %%
print(x)
# Out:
# 27

# %%
y="Maria"

# %%
print(y)
# Out:
# Maria

# %%
y="eva"

# %%
print(y)
# Out:
# eva

# %%
new_list = [23,24,25,26]

# %%
new_list
# Out:
# [23, 24, 25, 26]

# %%
new_list [0]            #pos 0,1,2,3
# Out:
# 23

# %%
new_list [3]
# Out:
# 26

# %%
new_list [-1]           #von hinten
# Out:
# 26

# %%
len(new_list)             #länge ausgeben
# Out:
# 4

# %%
new_list [1:4]
# Out:
# [24, 25, 26]

# %%
new_list [-1] = 37    #element austauschen

# %%
new_list
# Out:
# [23, 24, 25, 37]

# %%
new_list [1:3] = [30,31]

# %%
new_list
# Out:
# [23, 30, 31, 37]

# %%
new_list.append (36)    #hinzufügen

# %%
new_list
# Out:
# [23, 30, 31, 37, 36]

# %%
new_list.remove(36)     #löschen

# %%
new_list
# Out:
# [23, 30, 31, 37]

# %%
new_list.pop(-1)      #letztes zeichen löschen
# Out:
# 37

# %%
new_list
# Out:
# [23, 30, 31]

# %%
del new_list[2]     #zeichen nr 2 löschen

# %%
new_list
# Out:
# [23, 30]

# %%
for x in range(0,2001,500):     #start,stop,step
  print(x)
# Out:
# 0
# 500
# 1000
# 1500
# 2000

# %%
a = 23
b = 27

if a > b:
  print("a is bigger than b")
elif a < b:
  print("a is smaller than b")
else:
  print("a is equal to b")
# Out:
# a is smaller than b

# %%
a = input("Wie alt ist deine Schwester? : \n")
b = input("Wie alt ist dein Bruder? : \n")

if a > b:
  print("Deine Schwester ist älter als dein Bruder")
elif a < b:
  print("Dein Bruder ist älter als deine Schwester")
else:
  print("Es sind Zwillinge")

# %%
import random

random_side = random.randint(0, 1)
if random_side == 1:
  print("Head")
else:
  print("Tail")
# Out:
# Tail

# %%
import random

random_side = random.randint(0, 2)
if random_side == 1:
  print("Head")
elif random_side == 0:
  print("Tail")
else:
  print("Seite")
# Out:
# Tail

# %%
import random

user_seite = random.randint(0, 1)
comp_seite = random.randint(0, 1)

if user_seite == 1:
  print("You choose Heads")
elif user_seite == 0:
    print("You choose Tails")

if comp_seite == 1:
  print("Computer choose Heads")
elif comp_seite == 0:
  print("Computer choose Tails")

if comp_seite > user_seite:
  print("You lose!")
elif user_seite > comp_seite:
  print("You win!")
else:
  print("Draw!")

# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''
paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''
scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

# %%
game_images = [rock, paper, scissors]

# %%
user_choice = int(input("What do you choose? Type 0 for rock, 1 for paper, 2 for scissors.")) 
print("You choose:")
print(game_images[user_choice])

import random
computer_choice = random.randint(0,2)
print("Computer chose:")
print(game_images[computer_choice])


if user_choice ==0 and computer_choice ==2:
  print("You win!")
elif user_choice ==2 and computer_choice ==0:
  print("You lose!")
elif user_choice  ==1 and computer_choice ==2:
  print("You lose!")
elif user_choice ==2 and computer_choice ==1:
  print("You win!")
elif user_choice ==0 and computer_choice ==1:
  print("You lose!")
elif user_choice ==1 and computer_choice ==0:
  print("You win!")
elif user_choice == computer_choice:
  print("It's a draw!")

# %%
# rock, paper and scissors games

# import random package
import random

# ASCII Arts for rock, paper and scissors
# Adding ASCII art into a variable

rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

# Adding Game Images into a list
game_images = [rock, paper, scissors]

# Taking input from user choice
user_choice = int(input(
    "What do you choose? Type 0 for Rock, 1 for Paper, 2 for scissor. \n => "))

print("User Choice: ")    

# print game image by user choice
print(game_images[user_choice])

# random computer choice
computer_choice = random.randint(0, 2)

print("Computer Choice: ")

# print game image by computer choice
print(game_images[computer_choice])

# rules in logic
if user_choice == 0 and computer_choice == 2:
    print("You win! 🎉")
elif computer_choice == 0 and user_choice == 2:
    print("You lose.  ☠")
elif computer_choice > user_choice:
    print("You lose. ☠")
elif user_choice > computer_choice:
    print("You win!🎉 ")
elif computer_choice == user_choice:
    print("It's a draw.")
elif user_choice >= 3 or user_choice < 0:
    print("You typed an invalid number, You Lose.  ☠")
# Out:
# What do you choose? Type 0 for Rock, 1 for Paper, 2 for scissor.
#  => 2
# User Choice:
#
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
# Computer Choice:
#
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# You win!🎉
